# %% [markdown]
# # Concepts

# %% [markdown]
# *   Printing to the Console in Python
# * String Manipulation
# * Debugging
# * The Python Input Function
# * Python Variables
# * Variable Naming

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World \n Hello World")
# Out:
# Hello World
#  Hello World
