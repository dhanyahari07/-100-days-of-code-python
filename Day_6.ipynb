# %% [markdown]
# * code blocks
# * functions
# * while loop

# %%
print("hello")
# Out:
# hello

# %%
def my_function():
  print("hello")
  print("hai")

# %%
my_function()
# Out:
# hello
# hai

# %%
def turn_right():
    turn_left()
    turn_left()
    turn_left()

while front_is_clear():
    move()
turn_left()

while not at_goal():
    if right_is_clear():
        turn_right()
        move()
    elif front_is_clear():
        move()
    else:
        turn_left()
