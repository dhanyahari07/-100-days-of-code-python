# %%
programming_dictionary = {
    "Bug": "An error in a program that prevents the program from running as expected.",
    "Function": "A piece of code that you can easily call over and over again.",
}

# %%
print(programming_dictionary)
# Out:
# {'Bug': 'An error in a program that prevents the program from running as expected.', 'Function': 'A piece of code that you can easily call over and over again.'}

# %%
programming_dictionary["Loop"] = "The action of doing something receptively"

# %%
empty_dictionary = {}

# %%
programming_dictionary = {}
print(programming_dictionary) # Will return nothing
# Out:
# {}

# %%
programming_dictionary["Bug"] = "Bug has been edited."
print(programming_dictionary)
# Out:
# {'Bug': 'Bug has been edited.'}

# %%
for key in programming_dictionary:
    print(f"{key} : {programming_dictionary[key]}")
# Out:
# Bug : Bug has been edited.

# %%
student_scores = {
  "Dhanya": 81,
  "Hari": 78,
  "Appu": 99,
  "Alice": 74,
  "Bob": 62,
}

student_grades ={}


for key in student_scores:
    student_grades[key] = student_scores[key]

print(f"this is the std. scores: {student_scores}")

for key in student_grades:
    if student_scores[key] > 91:
        student_grades[key] = "Outstanding"
    elif 81 < student_scores[key] < 90:
        student_grades[key] = "Exceeds Expectations"
    elif 71 < student_scores[key] < 80:
        student_grades[key] = "Acceptable"
    else:
        student_grades[key] = "Fail"

print(student_scores)
print(student_grades)
# Out:
# this is the std. scores: {'Dhanya': 81, 'Hari': 78, 'Appu': 99, 'Alice': 74, 'Bob': 62}
# {'Dhanya': 81, 'Hari': 78, 'Appu': 99, 'Alice': 74, 'Bob': 62}
# {'Dhanya': 'Fail', 'Hari': 'Acceptable', 'Appu': 'Outstanding', 'Alice': 'Acceptable', 'Bob': 'Fail'}
