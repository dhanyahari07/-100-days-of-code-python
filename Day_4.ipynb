# %% [markdown]
# # Random
# * Merssene twister

# %%
import random
random_int=random.randint(1,10)
print(random_int)
# Out:
# 6

# %%
rand_num_0_1=random.random() *10  # random between 0 and 10
print(rand_num_0_1)
#
# Out:
# 3.0925869643621082

# %%
rand_float=random.uniform(1,10)
print(rand_float)
#
# Out:
# 6.618661737253482

# %%
rand_heads_tails=random.randint(0,1)
if rand_heads_tails==0:
    print("heads")
else:
    print("tails")
# Out:
# heads

# %% [markdown]
# # List

# %%
states_of_america=["Delaware","Pennsylvania","New Jersey"]
print(states_of_america[0])
print(states_of_america[-1])
# Out:
# Delaware
# New Jersey

# %%
states_of_america[1]="Pencilvania"
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey']

# %%
states_of_america.append("Florida")
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey', 'Florida']

# %%
states_of_america.extend(["Alaska","Hawaii"])
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey', 'Florida', 'Alaska', 'Hawaii']

# %% [markdown]
# # who will pay the bill

# %%
friends=["Alice","Bob","Charlie","David","Emanuel"]
print(friends)
# Out:
# ['Alice', 'Bob', 'Charlie', 'David', 'Emanuel']

# %%
print(random.choice(friends))
# Out:
# Alice

# %%
random_index=random.randint(0,len(friends)-1)
print(friends[random_index])
# Out:
# Emanuel

# %%
friends_str=", ".join(friends)
print(friends_str)
#
# Out:
# Alice, Bob, Charlie, David, Emanuel

# %%
states_of_america[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2692136459.py in <cell line: 0>()
# ----> 1 states_of_america[6]
#
# IndexError: list index out of range

# %%
#dirty_dozen=["Strawberries","Spinach,Nectarines","Apples","Grapes","Peas"]

fruits=["strabberries","Nectarines","Apples","Grapes","Peaches"]
vegetables=["Spinach","Kale","Tomatoes","Celery","Potatoes"]
dirty_dozen=[fruits,vegetables]
print(dirty_dozen)
# Out:
# [['strabberries', 'Nectarines', 'Apples', 'Grapes', 'Peaches'], ['Spinach', 'Kale', 'Tomatoes', 'Celery', 'Potatoes']]

# %%
dirty_dozen[1][1]
# Out:
# 'Kale'

# %% [markdown]
# # rock paper scissors

# %%
rock='''        _
               | |
 _ __ ___   ___| | __
| '__/ _ \\ / __| |/ /
| | | (_) | (__|   <
|_|  \\___/ \\___|_|\\_\

                  '''

# %%
paper='''

 _ __   __ _ _ __   ___ _ __
| '_ \\ / _` | '_ \\ / _ \\ '__|
| |_) | (_| | |_) |  __/ |
| .__/ \\__,_| .__/ \\___|_|
| |         | |
|_|         |_|

'''

# %%
scissors='''
     _
         (_)
 ___  ___ _ ___ ___  ___  _ __ ___
/ __|/ __| / __/ __|/ _ \\| '__/ __|
\\__ \\ (__| \\__ \\__ \\ (_) | |  \\__ \\
|___/\\___|_|___/___/\\___/|_|  |___/

                  '''

# %%
print(rock)
# Out:
#         _
#                | |
#  _ __ ___   ___| | __
# | '__/ _ \ / __| |/ /
# | | | (_) | (__|   <
# |_|  \___/ \___|_|\_

# %%
game_images = [rock, paper, scissors]

user_choice = int(input("What do you choose? Type 0 for Rock, 1 for Paper or 2 for Scissors.\n"))
print(game_images[user_choice])

computer_choice = random.randint(0, 2)
print("Computer chose:")
print(game_images[computer_choice])

if user_choice >= 3 or user_choice < 0:
  print("You typed an invalid number, you lose!")
elif user_choice == 0 and computer_choice == 2:
  print("You win!")
elif computer_choice == 0 and user_choice == 2:
  print("You lose")
elif computer_choice > user_choice:
  print("You lose")
elif user_choice > computer_choice:
  print("You win!")
elif computer_choice == user_choice:
  print("It's a draw")
# Out:
# What do you choose? Type 0 for Rock, 1 for Paper or 2 for Scissors.
# 0
#         _
#                | |
#  _ __ ___   ___| | __
# | '__/ _ \ / __| |/ /
# | | | (_) | (__|   <
# |_|  \___/ \___|_|\_
#
# Computer chose:
#         _
#                | |
#  _ __ ___   ___| | __
# | '__/ _ \ / __| |/ /
# | | | (_) | (__|   <
# |_|  \___/ \___|_|\_
#
# It's a draw
